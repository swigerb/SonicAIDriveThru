# %% [markdown]
# # Sonic Drive-In Menu Ingestion to Azure AI Search
#
# ## 1: Notebook Introduction
# This notebook demonstrates how to:
# 1. Configure Azure OpenAI and Azure AI Search services for the Sonic Drive-In menu.
# 2. Prepare the Sonic menu JSON data for ingestion into Azure AI Search.
# 3. Upload the prepared data to Azure AI Search for hybrid semantic search capabilities.

# %% [markdown]
# ## 2: Install Required Packages
#
# ### Description
# This cell installs all the necessary packages required for the notebook.
# It ensures that all dependencies are met before proceeding with the rest of the notebook.

# %%
# %pip install azure-core azure-search-documents python-dotenv langchain-openai langchain-community openai==1.54.3 "httpx>=0.23.0,<0.28.0" pydantic tenacity
# Out:
# Requirement already satisfied: azure-core in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (1.36.0)
# Requirement already satisfied: azure-search-documents in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (11.6.0)
# Requirement already satisfied: python-dotenv in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (1.0.1)
# Requirement already satisfied: langchain-openai in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (0.2.11)
# Requirement already satisfied: langchain-community in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (0.3.31)
# Requirement already satisfied: openai==1.54.3 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (1.54.3)
# Collecting httpx<0.28.0,>=0.23.0
#   Using cached httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: pydantic in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (2.12.5)
# Requirement already satisfied: tenacity in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (9.1.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from openai==1.54.3) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from openai==1.54.3) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from openai==1.54.3) (0.13.0)
# Requirement already satisfied: sniffio in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from openai==1.54.3) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from openai==1.54.3) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from openai==1.54.3) (4.15.0)
# Requirement already satisfied: certifi in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from httpx<0.28.0,>=0.23.0) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from httpx<0.28.0,>=0.23.0) (1.0.9)
# Requirement already satisfied: idna in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from httpx<0.28.0,>=0.23.0) (3.11)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: h11>=0.16 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<0.28.0,>=0.23.0) (0.16.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from azure-core) (2.32.5)
# Requirement already satisfied: azure-common>=1.1 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from azure-search-documents) (1.1.28)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from azure-search-documents) (0.7.2)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.21 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-openai) (0.3.83)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai) (0.4.54)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai) (6.0.3)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\brswig\appdata\roaming\python\python312\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai) (25.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<0.4.0,>=0.3.21->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.21->langchain-openai) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.21->langchain-openai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.21->langchain-openai) (0.25.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2025.11.3)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (3.10.11)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (2.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain<2.0.0,>=0.3.27->langchain-community) (0.3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.21.0->azure-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.21.0->azure-core) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: propcache>=0.2.1 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: colorama in c:\users\brswig\appdata\roaming\python\python312\site-packages (from tqdm>4->openai==1.54.3) (0.4.6)
# Using cached httpx-0.27.2-py3-none-any.whl (76 kB)
# Installing collected packages: httpx
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
# Successfully installed httpx-0.27.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 3: Imports and Environment Setup
#
# ### Description
# This cell imports necessary libraries and loads environment variables using `dotenv`.
# Ensure your `.env` file is properly set up with the required Azure API keys and endpoints.

# %%
# Import required libraries
from azure.core.credentials import AzureKeyCredential
from azure.core.exceptions import HttpResponseError
from azure.search.documents import SearchClient
from azure.search.documents.indexes import SearchIndexClient
from azure.search.documents.indexes.models import (
    SearchIndex,
    SimpleField,
    SearchField,
    SearchFieldDataType,
    VectorSearch,
    HnswAlgorithmConfiguration,
    VectorSearchProfile,
    AzureOpenAIVectorizer,
    AzureOpenAIVectorizerParameters,
    SemanticConfiguration,
    SemanticPrioritizedFields,
    SemanticField,
    SemanticSearch
)
from dotenv import load_dotenv
from openai import AzureOpenAI
from tenacity import retry, stop_after_attempt, wait_exponential

import json
import os
import re

# Load environment variables from the repo backend .env (fallback to current dir)
env_path = os.path.join('..', 'app', 'backend', '.env')
load_dotenv(dotenv_path=env_path)
load_dotenv()  # allows overriding with local .env if present
print(f'Loaded env file at {env_path}: {os.path.exists(env_path)}')
# Out:
# Loaded env file at ..\app\backend\.env: True

# %% [markdown]
# ## 4: Azure OpenAI and Azure AI Search Configuration
#
# ### Description
# This cell sets up the Azure OpenAI and AI Search configurations.
# Ensure that the endpoints, API keys, and deployment names in the `.env` file match your Azure resource setup.
#
# **Note:** This notebook uses the `sonic-menu-items` index name, distinct from other indexes in the project.

# %%
# Quick credential sanity check (prints masked values)
def _mask(val: str):
    if not val:
        return '<missing>'
    return f'len={len(val)}, suffix={val[-4:]}'

vars_to_check = {
    'AZURE_OPENAI_EASTUS_ENDPOINT': os.getenv('AZURE_OPENAI_EASTUS_ENDPOINT'),
    'AZURE_OPENAI_EASTUS_API_KEY': os.getenv('AZURE_OPENAI_EASTUS_API_KEY') or os.getenv('AZURE_OPENAI_API_KEY'),
    'AZURE_OPENAI_API_VERSION': os.getenv('AZURE_OPENAI_API_VERSION'),
    'AZURE_OPENAI_EMBEDDING_DEPLOYMENT': os.getenv('AZURE_OPENAI_EMBEDDING_DEPLOYMENT'),
    'AZURE_SEARCH_ENDPOINT': os.getenv('AZURE_SEARCH_ENDPOINT'),
    'AZURE_SEARCH_API_KEY': os.getenv('AZURE_SEARCH_API_KEY'),
}

# Normalize to expected variable if only generic name is present
if not os.getenv('AZURE_OPENAI_EASTUS_API_KEY') and os.getenv('AZURE_OPENAI_API_KEY'):
    os.environ['AZURE_OPENAI_EASTUS_API_KEY'] = os.getenv('AZURE_OPENAI_API_KEY')

for name, value in vars_to_check.items():
    print(f'{name}: {_mask(value)}')

missing = [k for k, v in vars_to_check.items() if not v]
if missing:
    raise RuntimeError(f"Missing required environment variables: {', '.join(missing)}")
else:
    print('All required environment variables are present.')
# Out:
# AZURE_OPENAI_EASTUS_ENDPOINT: len=56, suffix=com/
# AZURE_OPENAI_EASTUS_API_KEY: len=32, suffix=7f92
# AZURE_OPENAI_API_VERSION: len=10, suffix=0-21
# AZURE_OPENAI_EMBEDDING_DEPLOYMENT: len=22, suffix=arge
# AZURE_SEARCH_ENDPOINT: len=47, suffix=.net
# AZURE_SEARCH_API_KEY: len=52, suffix=5Upz
# All required environment variables are present.

# %%
# Azure OpenAI setup
aoai_eastus_endpoint = os.getenv('AZURE_OPENAI_EASTUS_ENDPOINT')
aoai_eastus_api_key = os.getenv('AZURE_OPENAI_EASTUS_API_KEY')
aoai_openai_api_version = os.getenv('AZURE_OPENAI_API_VERSION')
aoai_embedding_deployment = os.getenv('AZURE_OPENAI_EMBEDDING_DEPLOYMENT')

# Initialize the Azure OpenAI client
aoai_client = AzureOpenAI(
    azure_endpoint=aoai_eastus_endpoint,
    api_version=aoai_openai_api_version,
    api_key=aoai_eastus_api_key,
)

# Sonic Drive-In search index name
index_name = 'sonic-menu-items'

# Azure AI Search credentials
search_service_endpoint = os.getenv('AZURE_SEARCH_ENDPOINT')
search_api_key = os.getenv('AZURE_SEARCH_API_KEY')
search_client = SearchClient(endpoint=search_service_endpoint, index_name=index_name, credential=AzureKeyCredential(search_api_key))
search_index_client = SearchIndexClient(endpoint=search_service_endpoint, credential=AzureKeyCredential(search_api_key))

print(f'Azure OpenAI and Azure Search clients initialized successfully.')
print(f'Target index: {index_name}')
# Out:
# Azure OpenAI and Azure Search clients initialized successfully.
# Target index: sonic-menu-items

# %% [markdown]
# ## 5: Define and Create/Update Index Schema with Semantic Configuration
#
# ### Description
# This cell defines the schema for the Sonic Drive-In Azure AI Search index, including fields for semantic search and vector search capabilities. It deletes any existing index with the same name and creates a fresh one.

# %% [markdown]
# ### Note on enabling semantic ranker
#
# Semantic search is a service-level capability. If you see errors like "semantic search is not enabled," ensure the service has semantic ranker turned on (Standard tier or higher). You can enable it via CLI if the portal UI does not surface a toggle:
#
# `az search service update --name <service> --resource-group <rg> --semantic-search standard`
#
# Once enabled, the existing index schema here (with `semantic_search` and `menuSemanticConfig`) works without further changes.

# %%
# Define and Create/Update Index Schema with Semantic Configuration
if not index_name:
    raise RuntimeError('index_name is not set.')

index_schema = SearchIndex(
    name=index_name,
    fields=[
        SimpleField(name='id', type=SearchFieldDataType.String, key=True, sortable=True, filterable=True),
        SearchField(name='category', type=SearchFieldDataType.String, sortable=True, filterable=True, facetable=True),
        SearchField(name='name', type=SearchFieldDataType.String, sortable=True, filterable=True, facetable=True),
        SearchField(name='description', type=SearchFieldDataType.String),
        SearchField(name='longDescription', type=SearchFieldDataType.String),
        SearchField(name='origin', type=SearchFieldDataType.String, filterable=True, facetable=True),
        SearchField(name='caffeineContent', type=SearchFieldDataType.String, filterable=True),
        SearchField(name='brewingMethod', type=SearchFieldDataType.String, filterable=True),
        SearchField(name='popularity', type=SearchFieldDataType.String, filterable=True, facetable=True),
        SearchField(name='image', type=SearchFieldDataType.String, filterable=False, facetable=False),
        SearchField(name='sizes', type=SearchFieldDataType.String, filterable=False, facetable=False),
        SearchField(
            name='embedding',
            type=SearchFieldDataType.Collection(SearchFieldDataType.Single),
            vector_search_dimensions=3072,
            vector_search_profile_name='menuHnswProfile'
        )
    ],
    vector_search=VectorSearch(
        algorithms=[
            HnswAlgorithmConfiguration(
                name='menuHnsw',
                kind='hnsw',
                parameters={'m': 10, 'efConstruction': 200}
            )
        ],
        profiles=[
            VectorSearchProfile(
                name='menuHnswProfile',
                algorithm_configuration_name='menuHnsw',
                vectorizer_name='menuVectorizer'
            )
        ],
        vectorizers=[
            AzureOpenAIVectorizer(
                vectorizer_name='menuVectorizer',
                parameters=AzureOpenAIVectorizerParameters(
                    resource_url=aoai_eastus_endpoint,
                    deployment_name=aoai_embedding_deployment,
                    model_name=aoai_embedding_deployment,
                    api_key=aoai_eastus_api_key
                )
            )
        ]
    ),
    semantic_search=SemanticSearch(
        configurations=[
            SemanticConfiguration(
                name='menuSemanticConfig',
                prioritized_fields=SemanticPrioritizedFields(
                    title_field=SemanticField(field_name='name'),
                    content_fields=[
                        SemanticField(field_name='description'),
                        SemanticField(field_name='longDescription'),
                        SemanticField(field_name='category')
                    ]
                )
            )
        ]
    ),
)

# Delete the existing index if it exists
try:
    search_index_client.delete_index(index_name)
    print(f'Deleted existing index: {index_name}')
except Exception as e:
    print(f'Index {index_name} does not exist or could not be deleted: {e}')

# Create the index schema
try:
    search_index_client.create_or_update_index(index=index_schema)
    print(f'Created index: {index_name}')
except Exception as e:
    raise RuntimeError(f'Failed to create/update index {index_name}: {e}')

# Verify index exists
existing = [i.name for i in search_index_client.list_indexes()]
print(f'Indexes present: {existing}')
if index_name not in existing:
    raise RuntimeError(f'Index {index_name} was not found after creation.')
# Out:
# Deleted existing index: sonic-menu-items
# Created index: sonic-menu-items
# Indexes present: ['coffee-chat', 'sonic-menu-items']

# %% [markdown]
# ## 6: Load and Process Production Sonic Drive-In Menu Data
#
# ### Description
# This cell reads the production `sonic-menu-items.json` file, which uses a nested structure with `menus`, `products`, `categories`, and `productGroups`. It recursively traverses categories to find leaf products, resolves size variants from productGroups, and builds the structured menu items list.

# %%
# Load production Sonic menu data (nested menus/products/categories/productGroups format)
menu_data_candidates = [
    os.path.join('..', 'app', 'frontend', 'src', 'data', 'sonic-menu-items.json'),
]

menu_data_path = None
for candidate in menu_data_candidates:
    if os.path.exists(candidate):
        menu_data_path = candidate
        break

if not menu_data_path:
    raise FileNotFoundError(f'Could not find sonic-menu-items.json. Tried: {menu_data_candidates}')

print(f'Using sonic-menu-items.json at: {menu_data_path}')

with open(menu_data_path, 'r', encoding='utf-8') as file:
    raw_data = json.load(file)

# Access first menu dynamically
menu = list(raw_data['menus'].values())[0]
products = menu['products']
categories = menu['categories']
product_groups = menu['productGroups']

print(f'Menu: {menu.get("displayName", "unknown")}')
print(f'Total products: {len(products)}, Categories: {len(categories)}, ProductGroups: {len(product_groups)}')


def collect_products_from_category(cat_id, categories, leaf_name=None):
    """Recursively traverse categories, collecting (product_id, leaf_category_name) tuples."""
    cat = categories.get(cat_id)
    if not cat:
        return []
    current_name = leaf_name or cat.get('displayName', cat_id)
    result = []
    for ref in cat.get('childRefs', {}).keys():
        if ref.startswith('categories.'):
            sub_cat_id = ref[len('categories.'):]
            # Use the subcategory's own name as the leaf name
            sub_cat = categories.get(sub_cat_id)
            sub_name = sub_cat.get('displayName', sub_cat_id) if sub_cat else sub_cat_id
            result.extend(collect_products_from_category(sub_cat_id, categories, sub_name))
        elif ref.startswith('products.'):
            prod_id = ref[len('products.'):]
            result.append((prod_id, current_name))
    return result


# Collect all products referenced from top-level categories
product_category_map = {}  # product_id -> leaf category name

# Find top-level categories (not referenced as child of another category)
child_cat_ids = set()
for cat in categories.values():
    for ref in cat.get('childRefs', {}).keys():
        if ref.startswith('categories.'):
            child_cat_ids.add(ref[len('categories.'):])

top_level_cats = [cid for cid in categories.keys() if cid not in child_cat_ids]
print(f'Top-level categories: {len(top_level_cats)}')

for cat_id in top_level_cats:
    for prod_id, leaf_cat_name in collect_products_from_category(cat_id, categories):
        if prod_id not in product_category_map:
            product_category_map[prod_id] = leaf_cat_name

print(f'Products found via category traversal: {len(product_category_map)}')


def normalize_size_name(child_display_name, parent_display_name):
    """Extract clean size label from verbose product-specific display name."""
    prefixes = [
        ("Mini ", "Mini"),
        ("Sm ", "Small"),
        ("Med ", "Medium"),
        ("Lg ", "Large"),
        ("RT 44", "RT 44"),
        ("Rt. 44", "RT 44"),
    ]
    for prefix, label in prefixes:
        if child_display_name.startswith(prefix):
            return label
    # Fallback: strip parent name from child name
    stripped = child_display_name.replace(parent_display_name, '').strip()
    # Remove ® and other trademark symbols
    stripped = stripped.replace('\u00ae', '').strip()
    if stripped:
        return stripped
    return "Standard"


def get_size_variants(product, products, product_groups):
    """Resolve size variants for a product from relatedProducts.alternatives."""
    alternatives = product.get('relatedProducts', {}).get('alternatives', {})
    sizes = []
    for group_ref in alternatives.keys():
        if group_ref.startswith('productGroups.'):
            group_id = group_ref[len('productGroups.'):]
            group = product_groups.get(group_id)
            if not group:
                continue
            for child_ref in group.get('childRefs', {}).keys():
                if child_ref.startswith('products.'):
                    child_id = child_ref[len('products.'):]
                    child_product = products.get(child_id)
                    if child_product:
                        sizes.append({
                            'size': normalize_size_name(child_product.get('displayName', child_id), product.get('displayName', '')),
                            'price': child_product.get('price', 0.0)
                        })
    return sizes


# Build structured menu items
structured_menu_items = []

for prod_id, cat_name in product_category_map.items():
    product = products.get(prod_id)
    if not product:
        continue
    # Filter: only non-recipe products
    if product.get('isRecipe', False):
        continue

    size_variants = get_size_variants(product, products, product_groups)
    if not size_variants:
        # No size alternatives -- use product's own price
        price = product.get('price', 0.0) or 0.0
        size_variants = [{'size': 'Standard', 'price': price}]

    structured_menu_items.append({
        'productId': prod_id,
        'name': product.get('displayName', prod_id),
        'description': product.get('description', ''),
        'imageUrl': product.get('imageUrl', ''),
        'category': cat_name,
        'sizes': size_variants,
    })

print(f'\nTotal menu items for ingestion: {len(structured_menu_items)}')

# Show category distribution
from collections import Counter
cat_counts = Counter(item['category'] for item in structured_menu_items)
print(f'\nCategory distribution ({len(cat_counts)} categories):')
for cat, count in cat_counts.most_common():
    print(f'  {cat}: {count}')

# Preview first 3 items
print(f'\n--- Sample items ---')
for item in structured_menu_items[:3]:
    print(json.dumps(item, indent=2))

# %% [markdown]
# ## 7: Data Preparation and Embedding Generation
#
# ### Description
# This cell defines functions to sanitize document keys, generate embeddings using Azure OpenAI, and prepare the Sonic Drive-In menu data for ingestion into Azure AI Search. It includes retry logic for embedding generation and assigns embeddings to each document.

# %%
def sanitize_key(key):
    """Sanitize the document key to contain only valid characters."""
    return re.sub(r'[^a-zA-Z0-9_\-]', '_', key)

@retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=5, max=60))
def generate_embeddings(texts):
    """Generate embeddings using Azure OpenAI with retry logic for a batch of texts."""
    response = aoai_client.embeddings.create(input=texts, model=aoai_embedding_deployment)
    return [res.embedding for res in response.data]


def generate_embeddings_batched(texts, batch_size=100):
    """Generate embeddings in batches to respect API limits."""
    all_embeddings = []
    for i in range(0, len(texts), batch_size):
        batch = texts[i:i + batch_size]
        print(f'  Generating embeddings for batch {i // batch_size + 1} ({len(batch)} items)...')
        embeddings = generate_embeddings(batch)
        all_embeddings.extend(embeddings)
    return all_embeddings


def prepare_data_for_azure_search(menu_items):
    """Transform Sonic Drive-In production menu data for Azure AI Search ingestion."""
    azure_search_documents = []
    texts_for_embedding = []

    for item in menu_items:
        doc_id = sanitize_key(item['productId'])
        name = item['name']
        category = item['category']
        description = item.get('description', '')
        image = item.get('imageUrl', '')

        combined_text = f"{name} {category} {description}"
        texts_for_embedding.append(combined_text)

        azure_search_documents.append({
            'id': doc_id,
            'name': name,
            'category': category,
            'description': description,
            'longDescription': description,
            'origin': '',
            'caffeineContent': '',
            'brewingMethod': '',
            'popularity': '',
            'image': image,
            'sizes': json.dumps(item['sizes']),
        })

    # Generate embeddings in batches
    print(f'Generating embeddings for {len(texts_for_embedding)} items...')
    embeddings = generate_embeddings_batched(texts_for_embedding, batch_size=100)

    for i, embedding in enumerate(embeddings):
        azure_search_documents[i]['embedding'] = embedding

    return azure_search_documents


documents_for_index = prepare_data_for_azure_search(structured_menu_items)

print(f'\nPrepared {len(documents_for_index)} documents for indexing.')
print(f'\n--- Sample document ---')
if documents_for_index:
    doc = documents_for_index[0]
    print(f"ID: {doc['id']}")
    print(f"Name: {doc['name']}")
    print(f"Category: {doc['category']}")
    print(f"Description: {doc['description'][:100]}")
    print(f"Image: {doc['image'][:80]}...")
    print(f"Sizes: {doc['sizes']}")
    print(f"Embedding dims: {len(doc['embedding'])}")
# Out:
# Generating embeddings for 172 items...
#   Generating embeddings for batch 1 (100 items)...
#   Generating embeddings for batch 2 (72 items)...
#
# Prepared 172 documents for indexing.
#
# --- Sample document ---
# ID: salted-caramel-toffee-croissant-bites-966d1583
# Name: Salted Caramel Toffee Croissant Bites
# Category: National Breakfast Entrees
# Description: Flakey Croissant Bites, fried to a golden brown, then dusted with salted caramel and toffee sugar
#
# Image: https://imagedelivery.net/cyuZzWywsYlsu7DPQZIgOg/4dc47659-9b01-4588-b8e5-1d99652...
# Sizes: [{"size": "Standard", "price": 1.99}]
# Embedding dims: 3072

# %% [markdown]
# ## 8: Upload to Azure AI Search
#
# ### Description
# This cell uploads the prepared Sonic Drive-In menu data to Azure AI Search.
# Ensure the Azure AI Search index is properly configured before running this step.

# %%
def upload_documents_to_search(documents):
    batch_size = 15
    total_batches = (len(documents) + batch_size - 1) // batch_size
    successful_uploads = 0

    for i in range(0, len(documents), batch_size):
        batch = documents[i:i + batch_size]
        try:
            response = search_client.upload_documents(documents=batch)
            successful_uploads += len(batch)
            print(f'Uploaded batch {i // batch_size + 1}/{total_batches} successfully. Batch size: {len(batch)}')
        except HttpResponseError as e:
            print(f'Error uploading batch {i // batch_size + 1}/{total_batches}: {e}')
            continue

    print(f'\nSonic menu items uploaded successfully. Total: {successful_uploads}/{len(documents)}')

print(f'Uploading {len(documents_for_index)} documents to index: {index_name}')
upload_documents_to_search(documents_for_index)
# Out:
# Uploading 172 documents to index: sonic-menu-items
# Uploaded batch 1/12 successfully. Batch size: 15
# Uploaded batch 2/12 successfully. Batch size: 15
# Uploaded batch 3/12 successfully. Batch size: 15
# Uploaded batch 4/12 successfully. Batch size: 15
# Uploaded batch 5/12 successfully. Batch size: 15
# Uploaded batch 6/12 successfully. Batch size: 15
# Uploaded batch 7/12 successfully. Batch size: 15
# Uploaded batch 8/12 successfully. Batch size: 15
# Uploaded batch 9/12 successfully. Batch size: 15
# Uploaded batch 10/12 successfully. Batch size: 15
# Uploaded batch 11/12 successfully. Batch size: 15
# Uploaded batch 12/12 successfully. Batch size: 7
#
# Sonic menu items uploaded successfully. Total: 172/172

# %% [markdown]
# ## 9: Testing Search Capabilities
#
# ### Summary
# Test the Sonic Drive-In menu search index with various query types:
# - Simple text-based search for "burger"
# - Semantic search for "frozen drinks with fruit flavors"
# - Vector search for "crispy chicken sandwich with pickles"
# - Hybrid search combining text and vector for "cold refreshing slush"
# - Filter-based search for items in the "Shakes" category

# %%
# Test Azure AI Search with various query types
# %pip install --upgrade azure-search-documents
from azure.search.documents.models import VectorizedQuery


def perform_simple_search(query_text, filter_condition=None, top=5):
    """Perform a simple text-based search against the Sonic menu index"""
    results = search_client.search(
        search_text=query_text,
        filter=filter_condition,
        select=['id', 'name', 'description', 'category', 'sizes', 'image'],
        top=top,
        include_total_count=True
    )

    print(f"\n=== Simple Search Results for '{query_text}' ===")
    print(f'Total matches: {results.get_count()}')

    for result in results:
        print(f"\nName: {result['name']}")
        print(f"Category: {result['category']}")
        print(f"Description: {result['description']}")
        print('-' * 50)

    return results


def perform_semantic_search(query_text, top=5):
    """Perform a semantic search using the configured semantic settings"""
    try:
        results = search_client.search(
            search_text=query_text,
            select=['id', 'name', 'description', 'category', 'sizes', 'image'],
            top=top,
            query_type='semantic',
            semantic_configuration_name='menuSemanticConfig',
            include_total_count=True
        )
    except HttpResponseError as e:
        print('Semantic search is not enabled for this search service. Enable it in the Azure portal or use simple search instead.')
        print(f'Details: {e}')
        return None

    print(f"\n=== Semantic Search Results for '{query_text}' ===")
    print(f'Total matches: {results.get_count()}')

    for result in results:
        print(f"\nName: {result['name']}")
        print(f"Category: {result['category']}")
        print(f"Description: {result['description']}")
        print('-' * 50)

    return results


def perform_vector_search(query_text, top=5):
    """Generate embedding for the query and perform vector search"""
    client = AzureOpenAI(
        api_key=aoai_eastus_api_key,
        api_version='2023-05-15',
        azure_endpoint=aoai_eastus_endpoint
    )

    response = client.embeddings.create(input=query_text, model=aoai_embedding_deployment)
    query_vector = response.data[0].embedding

    vector_query = VectorizedQuery(vector=query_vector, k_nearest_neighbors=top, fields='embedding')
    results = search_client.search(
        search_text=None,
        select=['id', 'name', 'description', 'category', 'sizes', 'image'],
        top=top,
        vector_queries=[vector_query],
        include_total_count=True
    )

    print(f"\n=== Vector Search Results for '{query_text}' ===")
    print(f'Total matches: {results.get_count()}')

    for result in results:
        print(f"\nName: {result['name']}")
        print(f"Category: {result['category']}")
        print(f"Description: {result['description']}")
        print('-' * 50)

    return results


def perform_hybrid_search(query_text, top=5):
    """Perform a hybrid search combining vector search with text search"""
    client = AzureOpenAI(
        api_key=aoai_eastus_api_key,
        api_version='2023-05-15',
        azure_endpoint=aoai_eastus_endpoint
    )

    response = client.embeddings.create(input=query_text, model=aoai_embedding_deployment)
    query_vector = response.data[0].embedding

    vector_query = VectorizedQuery(vector=query_vector, k_nearest_neighbors=top, fields='embedding')
    results = search_client.search(
        search_text=query_text,
        select=['id', 'name', 'description', 'category', 'sizes', 'image'],
        top=top,
        vector_queries=[vector_query],
        include_total_count=True
    )

    print(f"\n=== Hybrid Search Results for '{query_text}' ===")
    print(f'Total matches: {results.get_count()}')

    for result in results:
        print(f"\nName: {result['name']}")
        print(f"Category: {result['category']}")
        print(f"Description: {result['description']}")
        print('-' * 50)

    return results


# Test different search types against the Sonic Drive-In menu
print('\n========= TESTING SONIC DRIVE-IN SEARCH CAPABILITIES =========')

# Test 1: Simple text search
simple_results = perform_simple_search('burger')

# Test 2: Semantic search for natural language queries
semantic_results = perform_semantic_search('frozen drinks with fruit flavors')

# Test 3: Vector search for semantic similarity
vector_results = perform_vector_search('crispy chicken sandwich with pickles')

# Test 4: Hybrid search combining text and vector capabilities
hybrid_results = perform_hybrid_search('cold refreshing slush')

# Test 5: Search with category filter
filtered_results = perform_simple_search(
    'shake',
    filter_condition="category eq 'Classic Shakes'"
)

# Test 6: Banana Shake -- verify sizes field has valid JSON with prices
print('\n========= BANANA SHAKE SIZE VERIFICATION =========')
shake_results = search_client.search(
    search_text='Banana Shake',
    select=['id', 'name', 'category', 'sizes', 'image'],
    top=3,
    include_total_count=True
)
for result in shake_results:
    print(f"\nName: {result['name']}")
    print(f"Category: {result['category']}")
    sizes_data = json.loads(result['sizes'])
    print(f"Sizes ({len(sizes_data)} variants):")
    for s in sizes_data:
        print(f"  {s['size']}: ${s['price']:.2f}")
    print(f"Image: {result.get('image', 'N/A')[:80]}")
    print('-' * 50)
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: azure-search-documents in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (11.6.0)
# Requirement already satisfied: azure-core>=1.28.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from azure-search-documents) (1.36.0)
# Requirement already satisfied: azure-common>=1.1 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from azure-search-documents) (1.1.28)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from azure-search-documents) (0.7.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from azure-search-documents) (4.15.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from azure-core>=1.28.0->azure-search-documents) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-search-documents) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-search-documents) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-search-documents) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-search-documents) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.
#
# ========= TESTING SONIC DRIVE-IN SEARCH CAPABILITIES =========
#
# === Simple Search Results for 'burger' ===
# Total matches: 0
#
# === Semantic Search Results for 'frozen drinks with fruit flavors' ===
# Total matches: 137
#
# Name: All Natural Lemonade
# Category: Lemonades & Limeades
# Description: All natural Lemonade, made with real fruit lemons.
# --------------------------------------------------
#
# Name: Strawberry Classic Shake
# Category: Classic Shakes
# Description: Our Strawberry Shake is made with creamy vanilla soft serve, real strawberries, and finished with whipped topping and a cherry.
# --------------------------------------------------
#
# Name: Cranberry Lemonade
# Category: Lemonades & Limeades
# Description: Tart all-natural lemonade, mixed with Cranberry flavor.
# --------------------------------------------------
#
# Name: Dragon Fruit Lemonade
# Category: Lemonades & Limeades
# Description: Tart all-natural lemonade, mixed with dragon fruit syrup.
# --------------------------------------------------
#
# Name: Strawberry Limeade
# Category: Lemonades & Limeades
# Description: Strawberry limeade made with lime and real strawberry.
# --------------------------------------------------
#
# === Vector Search Results for 'crispy chicken sandwich with pickles' ===
# Total matches: 5
#
# Name: Crispy Chicken Sandwich
# Category: National Chicken
# Description: A crispy chicken fillet with pickles, lettuce, and mayonnaise on a brioche bun.
# --------------------------------------------------
#
# Name: Crispy Chicken Sandwich Combo
# Category: Combos
# Description: The Crispy Chicken Sandwich served with your choice of Tots or Fries and a Medium Drink
# --------------------------------------------------
#
# Name: 3 Piece Crispy Tender Dinner
# Category: Local Chicken
# Description: Three pieces of perfectly breaded 100% all-white meat chicken Crispy Tenders, golden-brown Tots, a thick slice of warm Texas Toast, hand-made Onion Rings and your choice of sauce.
# --------------------------------------------------
#
# Name: Chicken Club TOASTER®
# Category: Local Chicken
# Description: Local Favorite! An all white meat, crispy chicken fillet topped with crispy bacon, melty cheese, lettuce, hand-sliced tomatoes, creamy mayo, and served between thick Texas Toast.
# --------------------------------------------------
#
# Name: Crispy Tenders Dinner - 3 piece
# Category: Combos
# Description: Crispy Tender Dinner with a piece of Texas Toast and a Signature Onion Ring served with your choice of Tots or Fries and a Medium Drink
# --------------------------------------------------
#
# === Hybrid Search Results for 'cold refreshing slush' ===
# Total matches: 37
#
# Name: Cherry Slush
# Category: Slushes
# Description: Sweet cherry icy slush
# --------------------------------------------------
#
# Name: Peach Slush
# Category: Slushes
# Description: Peach flavor and icy Slush
# --------------------------------------------------
#
# Name: Lemonade Slush
# Category: Slushes
# Description: Lemonade icy slush with real lemon
# --------------------------------------------------
#
# Name: Cherry Limeade Slush
# Category: Slushes
# Description: Cherry Limeade icy slush
# --------------------------------------------------
#
# Name: Strawberry Slush
# Category: Slushes
# Description: Strawberry icy slush with real strawberries
# --------------------------------------------------
#
# === Simple Search Results for 'shake' ===
# Total matches: 7
#
# Name: Peanut Butter Classic Shake
# Category: Classic Shakes
# Description: Our Peanut Butter Shake is made with sweet vanilla soft serve, creamy peanut butter and finished with whipped topping and a cherry.
# --------------------------------------------------
#
# Name: Vanilla Classic Shake
# Category: Classic Shakes
# Description: Our Vanilla Shake is made with creamy vanilla soft serve and finished with whipped topping and a cherry.
# --------------------------------------------------
#
# Name: Banana Classic Shake
# Category: Classic Shakes
# Description: Our Banana Shake is made with creamy vanilla soft serve, bananas and finished with whipped topping and a cherry.
# --------------------------------------------------
#
# Name: Caramel Classic Shake
# Category: Classic Shakes
# Description: Our Caramel Shake is made with creamy vanilla soft serve, rich caramel flavor and finished with whipped topping and a cherry.
# --------------------------------------------------
#
# Name: Chocolate Classic Shake
# Category: Classic Shakes
# Description: Our Chocolate Shake is made with creamy vanilla soft serve, rich chocolate sauce, and finished with whipped topping and a cherry.
# --------------------------------------------------
#
# ========= BANANA SHAKE SIZE VERIFICATION =========
#
# Name: Banana Classic Shake
# Category: Classic Shakes
# Sizes (4 variants):
#   Mini Banana Classic Shake: $3.39
#   Sm Banana Classic Shake: $4.19
#   Med Banana Classic Shake: $4.69
#   Lg Banana Classic Shake: $5.69
# Image: https://imagedelivery.net/cyuZzWywsYlsu7DPQZIgOg/8b707628-27df-43c1-abdc-a164487
# --------------------------------------------------
#
# Name: Peanut Butter Classic Shake
# Category: Classic Shakes
# Sizes (4 variants):
#   Mini Peanut Butter Classic Shake: $3.39
#   Sm Peanut Butter Classic Shake: $4.19
#   Med Peanut Butter Classic Shake: $4.69
#   Lg Peanut Butter Classic Shake: $5.69
# Image: https://imagedelivery.net/cyuZzWywsYlsu7DPQZIgOg/47745a83-d60d-4d45-8431-e989881
# --------------------------------------------------
#
# Name: Vanilla Classic Shake
# Category: Classic Shakes
# Sizes (4 variants):
#   Mini Vanilla Classic Shake: $3.39
#   Sm Vanilla Classic Shake: $4.19
#   Med Vanilla Classic Shake: $4.69
#   Lg Vanilla Classic Shake: $5.69
# Image: https://imagedelivery.net/cyuZzWywsYlsu7DPQZIgOg/b6ebeb24-53c7-4f63-7ecc-23fecf8
# --------------------------------------------------

# %% [markdown]
# ## 10: Final Summary
#
# ### Summary
# - Installed required packages.
# - Configured Azure OpenAI and Azure AI Search services.
# - Defined and created the `sonic-menu-items` index schema with semantic configuration (including `image` field).
# - Loaded and processed production Sonic Drive-In menu data from `sonic-menu-items.json`.
# - Recursively traversed categories to extract 172 non-recipe products with leaf-level category assignments.
# - Resolved size variants from productGroups for products with alternatives.
# - Generated embeddings and uploaded structured menu data into Azure AI Search.
# - Tested search capabilities with Sonic-relevant queries (burgers, slushes, shakes, etc.).
# - Verified size/price data integrity via Banana Shake query.
#
# The Sonic Drive-In menu ingestion pipeline is complete!
